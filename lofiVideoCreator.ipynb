# %%
# Created by: Tejaswi Kasat
# Version : 0.1
# This will create a lo-fi music video with watermarks

# All import statements
import os
import moviepy.editor as mp
import moviepy.video.fx.all as vfx


# All variables must be declared below
videosPath = "generatedVideos"
gifsPath = "downloadedGifs"
audioPath = "downloadedMusic"
totalTime = 180 # Time in seconds ~3mins

gifNames = os.listdir(gifsPath)
audioNames = os.listdir(audioPath)

for itr in range(0,len(gifNames)):
    try:
        gifPath = gifsPath + "/" + gifNames[itr]
        audioClipPath = audioPath + "/" + audioNames[itr]
        videoClip = mp.VideoFileClip(gifPath)

        # Calculating loops
        duration = videoClip.duration
        numOfLoops = totalTime/duration

        # Setting to Video
        videoClip = videoClip.fx(vfx.loop, n=numOfLoops)    
        audioClip = mp.AudioFileClip(audioClipPath)
        txt_clip = mp.TextClip("chill_music_addiction",fontsize=10,font='DejaVu-Sans-Bold',color='white', bg_color='black')
        txt_clip = txt_clip.set_position(("left","bottom")).set_duration(videoClip.duration)
        final = mp.CompositeVideoClip([videoClip,txt_clip])
        final.audio = audioClip
        final.write_videofile(videosPath+"/"+gifNames[itr]+".mp4",codec = "libx264", fps=25)
    except:
        print(e)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   1%|          | 17/1800 [3:08:38<00:35, 50.10it/s, now=None]
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:24<5559:22:34, 11124.93s/it, now=None]
#
#
#
#
#
#
#
#
#
# chunk:  40%|████      | 1595/3970 [2:58:06<00:05, 469.06it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1051/4500 [2:53:27<01:14, 46.45it/s, now=None]
#
#
#
#
# t:   0%|          | 1/1800 [3:06:22<5588:23:32, 11183.00s/it, now=None]
# t:   0%|          | 1/4500 [5:23:36<24265:13:05, 19416.49s/it, now=None]
#
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:04<5549:16:35, 11104.72s/it, now=None]
#
#
#
#
#
#
#
# chunk:   3%|▎         | 101/3970 [3:03:23<00:16, 231.74it/s, now=None]
#
#
#
#
#
#
#
#
#
#
# chunk:  90%|█████████ | 3972/4411 [6:39:46<00:00, 682.06it/s, now=None]A
#
#
# chunk:   3%|▎         | 101/3970 [3:11:12<00:12, 319.88it/s, now=None]
#
#
#
#
#
#
#
#
# t:   2%|▏         | 120/5940 [2:59:05<01:52, 51.91it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
# t:  18%|█▊        | 818/4500 [2:51:03<01:18, 46.78it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/1800 [2:47:36<5025:30:03, 10056.59s/it, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/4500 [2:46:12<12462:46:39, 9972.44s/it, now=None]
#
# chunk:   3%|▎         | 101/3970 [3:13:24<00:10, 354.49it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   1%|          | 17/1800 [3:08:38<00:35, 50.10it/s, now=None]
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:25<5559:27:24, 11125.09s/it, now=None]
#
#
#
#
#
#
#
#
#
# chunk:  40%|████      | 1595/3970 [2:58:07<00:05, 469.06it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1051/4500 [2:53:27<01:14, 46.45it/s, now=None]
#
#
#
#
# t:   0%|          | 1/1800 [3:06:23<5588:27:51, 11183.14s/it, now=None]
# t:   0%|          | 1/4500 [5:23:36<24265:23:51, 19416.63s/it, now=None]
#
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:04<5549:21:06, 11104.87s/it, now=None]
#
#
#
#
#
#
#
# chunk:   3%|▎         | 101/3970 [3:03:23<00:16, 231.74it/s, now=None]
#
#
#
#
#
#
#
#
#
#
# chunk:  90%|█████████ | 3972/4411 [6:39:46<00:00, 682.06it/s, now=None]A
#
#
# chunk:   3%|▎         | 101/3970 [3:11:13<00:12, 319.88it/s, now=None]
#
#
#
#
#
#
#
#
# t:   2%|▏         |
34it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  77%|███████▋  | 3066/3970 [00:05<00:01, 622.52it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  79%|███████▉  | 3130/3970 [00:05<00:01, 624.89it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  80%|████████  | 3194/3970 [00:05<00:01, 628.80it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  82%|████████▏ | 3257/3970 [00:05<00:01, 625.47it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  84%|████████▎ | 3320/3970 [00:05<00:01, 602.32it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  85%|████████▌ | 3384/3970 [00:05<00:00, 610.77it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  87%|████████▋ | 3448/3970 [00:05<00:00, 614.55it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  89%|████████▊ | 3516/3970 [00:05<00:00, 632.36it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  90%|█████████ | 3580/3970 [00:05<00:00, 624.40it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  92%|█████████▏| 3643/3970 [00:05<00:00, 591.26it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  93%|█████████▎| 3703/3970 [00:06<00:00, 580.47it/s, now=None]
# chunk:  95%|█████████▍| 3764/3970 [00:06<00:00, 588.11it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  96%|█████████▋| 3825/3970 [00:06<00:00, 592.98it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk:  98%|█████████▊| 3897/3970 [00:06<00:00, 625.84it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chunk: 100%|█████████▉| 3964/3970 [00:06<00:00, 635.65it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   1%|          | 17/1800 [3:08:45<00:35, 50.10it/s, now=None]
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:31<5562:48:29, 11131.80s/it, now=None]
#
#
#
#
#
#
#
#
#
# chunk:  40%|████      | 1595/3970 [2:58:13<00:05, 469.06it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1051/4500 [2:53:34<01:14, 46.45it/s, now=None]
#
#
#
#
# t:   0%|          | 1/1800 [3:06:29<5591:49:02, 11189.85s/it, now=None]
# t:   0%|          | 1/4500 [5:23:43<24273:46:58, 19423.34s/it, now=None]
#
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:11<5552:42:04, 11111.58s/it, now=None]
#
#
#
#
#
#
#
# chunk:   3%|▎         | 101/3970 [3:03:30<00:16, 231.74it/s, now=None]
#
#
#
#
#
#
#
#
#
#
# chunk:  90%|█████████ | 3972/4411 [6:39:53<00:00, 682.06it/s, now=None]A
#
#
# chunk:   3%|▎         | 101/3970 [3:11:19<00:12, 319.88it/s, now=None]
#
#
#
#
#
#
#
#
# t:   2%|▏         | 120/5940 [2:59:12<01:52, 51.91it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
# t:  18%|█▊        | 818/4500 [2:51:10<01:18, 46.78it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/1800 [2:47:43<5028:55:17, 10063.43s/it, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/4500 [2:46:19<12471:20:03, 9979.29s/it, now=None]
#
# chunk:   3%|▎         | 101/3970 [3:13:31<00:10, 354.49it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   1%|          | 17/1800 [3:08:45<00:35, 50.10it/s, now=None]
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:31<5562:52:03, 11131.92s/it, now=None]
#
#
#
#
#
#
#
#
#
# chunk:  40%|████      | 1595/3970 [2:58:13<00:05, 469.06it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1051/4500 [2:53:34<01:14, 46.45it/s, now=None]
#
#
#
#
# t:   0%|          | 1/1800 [3:06:29<5591:52:39, 11189.97s/it, now=None]
# t:   0%|          | 1/4500 [5:23:43<24273:56:03, 19423.46s/it, now=None]
#
#
#
#
#
#
# t:   0%|          | 1/1800 [3:05:11<5552:45:47, 11111.70s/it, now=None]
#
#
#
#
#
#
#
# chunk:   3%|▎         | 101/3970 [3:03:30<00:16, 231.74it/s, now=None]
#
#
#
#
#
#
#
#
#
#
# chunk:  90%|█████████ | 3972/4411 [6:39:53<00:00, 682.06it/s, now=None]A
#
#
# chunk:   3%|▎         | 101/3970 [3:11:19<00:12, 319.88it/s, now=None]
#
#
#
#
#
#
#
#
# t:   2%|▏         | 120/5940 [2:59:12<01:52, 51.91it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
# t:  18%|█▊        | 818/4500 [2:51:10<01:18, 46.78it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/1800 [2:47:43<5028:58:59, 10063.56s/it, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/4500 [2:46:19<12471:29:07, 9979.41s/it, now=None]
#
# chunk:   3%|▎         | 101/3970 [3:13:31<00:10, 354.49it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 0/4500 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video generatedVideos/0675e703-e3fe-4f80-bcde-d01eaaa0d30b.gif.mp4
# t:   0%|          | 3/4500 [00:00<02:41, 27.86it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          |
36it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  19%|█▉        | 846/4500 [00:12<00:58, 62.83it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  19%|█▉        | 861/4500 [00:12<00:49, 73.31it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  19%|█▉        | 871/4500 [00:13<00:56, 63.67it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  20%|█▉        | 882/4500 [00:13<01:01, 59.12it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  20%|█▉        | 897/4500 [00:13<00:50, 71.50it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  20%|██        | 907/4500 [00:13<00:56, 63.08it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  20%|██        | 917/4500 [00:13<00:50, 70.67it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  21%|██        | 926/4500 [00:13<00:54, 65.90it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  21%|██        | 940/4500 [00:13<00:45, 78.17it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  21%|██        | 950/4500 [00:14<00:55, 64.25it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  21%|██▏       | 963/4500 [00:14<00:58, 60.79it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  22%|██▏       | 978/4500 [00:14<00:47, 73.94it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  22%|██▏       | 988/4500 [00:14<00:55, 63.50it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  22%|██▏       | 1003/4500 [00:14<00:55, 63.34it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1017/4500 [00:15<00:46, 74.95it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1027/4500 [00:15<00:53, 64.74it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1041/4500 [00:15<00:46, 74.49it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  23%|██▎       | 1050/4500 [00:15<00:56, 61.01it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  24%|██▎       | 1063/4500 [00:15<00:58, 59.12it/s, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:  24%|██▍       | 1079/4500 [00:15<00:48, 70.73it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-d44667824940> in <module>
#      36         final.audio = audioClip
# ---> 37         final.write_videofile(videosPath+"/"+gifNames[itr]+".mp4",codec = "libx264", fps=25)
#      38     except:
#
# <decorator-gen-180> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#
# <decorator-gen-179> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     134
# --> 135     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-178> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     306                            ffmpeg_params=ffmpeg_params,
# --> 307                            logger=logger)
#     308
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     220         for t,frame in clip.iter_frames(logger=logger, with_times=True,
# --> 221                                         fps=fps, dtype="uint8"):
#     222             if withmask:
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in iter_frames(self, fps, with_times, logger, dtype)
#     471         for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472             frame = self.get_frame(t)
#     473             if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in get_frame(self, t)
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/compositing/CompositeVideoClip.py in make_frame(t)
#     110             for c in self.playing_clips(t):
# --> 111                     f = c.blit_on(f, t)
#     112             return f
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/VideoClip.py in blit_on(self, picture, t)
#     526
# --> 527         img = self.get_frame(ct)
#     528         mask = self.mask.get_frame(ct) if self.mask else None
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in get_frame(self, t)
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in <lambda>(t)
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in <lambda>(gf, t)
#     186
# --> 187         return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                        keep_duration=keep_duration)
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in get_frame(self, t)
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/VideoFileClip.py in <lambda>(t)
#     112
# --> 113             self.make_frame = lambda t: self.reader.get_frame(t)
#     114
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_reader.py in get_frame(self, t)
#     183             self.skip_frames(pos-self.pos-1)
# --> 184         result = self.read_frame()
#     185         self.pos = pos
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_reader.py in read_frame(self)
#     119
# --> 120         s = self.proc.stdout.read(nbytes)
#     121         if len(s) != nbytes:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-d44667824940> in <module>
#      37         final.write_videofile(videosPath+"/"+gifNames[itr]+".mp4",codec = "libx264", fps=25)
#      38     except:
# ---> 39         print(e)
#
# NameError: name 'e' is not defined

# %%
txt_clip = mp.TextClip("chill_music_addiction",fontsize=30,font='DejaVu-Sans-Bold',color='white', bg_color='black')
txt_clip = txt_clip.set_pos('bottom').set_duration(videoClip.duration)

# %%
final = mp.CompositeVideoClip([videoClip,txt_clip])

# %%
videoClip.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-77-ace9ada35b6d> in <module>
# ----> 1 videoClip.get_frame(25)
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in get_frame(self, t)
#      91                 return frame
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#      95     def fl(self, fun, apply_to=None, keep_duration=True):
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in <lambda>(gf, t)
#     185             apply_to = []
#     186
# --> 187         return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                        keep_duration=keep_duration)
#     189
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.6/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# ~/.local/lib/python3.6/site-packages/moviepy/Clip.py in get_frame(self, t)
#      91                 return frame
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#      95     def fl(self, fun, apply_to=None, keep_duration=True):
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/VideoFileClip.py in <lambda>(t)
#     111         else:
#     112
# --> 113             self.make_frame = lambda t: self.reader.get_frame(t)
#     114
#     115         # Make a reader for the audio, if any.
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_reader.py in get_frame(self, t)
#     182         else:
#     183             self.skip_frames(pos-self.pos-1)
# --> 184         result = self.read_frame()
#     185         self.pos = pos
#     186         return result
#
# ~/.local/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_reader.py in read_frame(self)
#     137                                "for instance the version in the repos is deprecated. "
#     138                                "Please update to a recent version from the website.")%(
# --> 139                                 self.filename))
#     140
#     141             result = self.lastread
#
# OSError: MoviePy error: failed to read the first frame of video file downloadedGifs/0675e703-e3fe-4f80-bcde-d01eaaa0d30b.gif. That might mean that the file is corrupted. That may also mean that you are using a deprecated version of FFMPEG. On Ubuntu/Debian for instance the version in the repos is deprecated. Please update to a recent version from the website.
